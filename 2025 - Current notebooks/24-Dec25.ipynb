# %% [markdown]
# # 2025 Dec 4<sup>th</sup> -- UQ PUG 24
#
# Welcome to UQ Python User Group! Check out our [general info](../readme.md) for how we work and what we do. Below you'll find the details of this month's gathering.
#
# ## Overview
#
# Welcome to the December UQ PUG! This month's *Pie-thon User Group* is special for three reasons
#
# * There were delicious, home-baked pies! Thank you An and Jo!
# * It was competitive: **worst pie chart wins**
# * It was the last one for 2025
#
# See below for details of the competition. Thanks for coming!
#
# ### Teams
#
# If you'd like to receive regular updates and post questions during the month, [join our Teams channel!](https://forms.office.com/Pages/ResponsePage.aspx?id=z3fjtrOdy0aRovrZYFuxXEzmI13TctBBiWhneXZv-1lUQ1MwQ0JUM0ZBS0hXV1NJSU04TEZEUFg2Si4u)
#
#
# ### Training Resources
#
# We offer Python training sessions and resources, you can find our introductory guide [here](https://github.com/uqlibrary/technology-training/blob/master/Python/python_intro/python_intro.md).

# %% [markdown]
# ## Introduce yourself
# | What's your name? | Where are you from? |
# | --- | --- |
# | Cameron | Library + SMP |
# | David | Library |
# | Nick | Library |
# | Lydia | Environment |
# | An | ADP |
# | Collins | PhD student |
# | Edison | Engineering |
# | Fran | * |

# %% [markdown]
# ## The Competition
#
# This month, after answering a few questions in the room, we ran a competition for the *worst pie chart*. See the entries below!
#
# | Contender | Chart |
# | --- | --- |
# | David | ![](../Demonstrations/pies/David.png) |
# | Lydia | ![](../Demonstrations/pies/Lydia.png) |
# | Cameron | ![](../Demonstrations/pies/Cameron.png) |
